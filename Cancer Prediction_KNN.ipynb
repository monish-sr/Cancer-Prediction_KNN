# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
df=pd.read_csv("Cancer_Data.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
if df.isnull().values.any():
    print("yes")
# Out:
# yes

# %%
#Encoding Diagnosis
df['diagnosis']=df['diagnosis'].astype('category')
df['diagnosis']=df['diagnosis'].cat.codes
df['diagnosis']
#Benign cancer (B)
#Malignant cancer (M)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int8

# %%
x=df[['radius_mean','texture_mean','perimeter_mean','area_worst']]
y=df[['diagnosis']]
x
#x = Features
#y = Target
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_worst
# 0          17.99         10.38          122.80      2019.0
# 1          20.57         17.77          132.90      1956.0
# 2          19.69         21.25          130.00      1709.0
# 3          11.42         20.38           77.58       567.7
# 4          20.29         14.34          135.10      1575.0
# ..           ...           ...             ...         ...
# 564        21.56         22.39          142.00      2027.0
# 565        20.13         28.25          131.20      1731.0
# 566        16.60         28.08          108.30      1124.0
# 567        20.60         29.33          140.10      1821.0
# 568         7.76         24.54           47.92       268.6
#
# [569 rows x 4 columns]

# %%
scaler=MinMaxScaler()
scaler
# Out:
# MinMaxScaler()

# %%
x=scaler.fit_transform(x)
x
# Out:
# array([[0.52103744, 0.0226581 , 0.54598853, 0.45069799],
#        [0.64314449, 0.27257355, 0.61578329, 0.43521431],
#        [0.60149557, 0.3902604 , 0.59574321, 0.37450845],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, 0.23073142],
#        [0.64456434, 0.66351031, 0.66553797, 0.402035  ],
#        [0.03686876, 0.50152181, 0.02853984, 0.02049744]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
y_test
# Out:
#      diagnosis
# 465          0
# 211          0
# 475          0
# 348          0
# 434          0
# ..         ...
# 220          0
# 461          1
# 416          0
# 483          0
# 285          0
#
# [171 rows x 1 columns]

# %%
knn = KNeighborsClassifier(n_neighbors=8)
knn.fit(x_train, y_train)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=8)

# %%
#if else prediction
y_pred=knn.predict([[0,0,0.299,0.33]])
if y_pred==0:
    print("Benign Cancer")
elif y_pred==1:
    print("Malignant Cancer")
y_pred
# Out:
# Benign Cancer
# array([0], dtype=int8)
